# %% [markdown]
#  Organizar arquivos por Ano.
#  Copia os arquivos e adiciona na pasta do respectivo ano ao que o arquivo foi criado.
#  Estaversão organiza os arquivos e copia a estrutura de diretórios que contém os arquivos.

# %%
#Importa as bibliotecas necessárias
import datetime
import os
import shutil

# %%
#Define o endereço de origem dos arquivos.
#path_origem = 'C:\\Users\\charlessodre\\Documents\\PastaVM\\Estudos\\OrganizadorArquivos\\source_img'
path_origem = 'D:\\FOTOS\\'

#Define o endereço de destino dos arquivos.
#path_destino = 'C:\\Users\\charlessodre\\Documents\\PastaVM\\Estudos\\OrganizadorArquivos\\DESTINO'
path_destino = 'D:\\FOTOS_POR_ANO'

# %%
#Define a Função para listar os arquivos e sub-diretórios.
def list_files_path(path):
    path_files = []
    for p, _, files in os.walk(os.path.abspath(path)):
        for file in files:
            path_files.append(os.path.join(p, file))
    
    return path_files

# %%
# Define a Função para Cria um diretório, a partir de uma lista, se não existir
def criar_diretorio_list(list_dir, path):
    for dir in list_dir:
        novo_dir = os.path.join(os.path.abspath(path), str(dir))
        
        if not os.path.exists(novo_dir):
            #print(novo_dir)
            os.mkdir(novo_dir)

# %%
# Define a Função para Cria um diretório, se não existir
def criar_diretorio(path, recursivo=False):
    if not os.path.exists(path):
        #print(novo_dir)
        if recursivo:
            os.makedirs(path)
        else:
            os.mkdir(path)

# %%
# Define a Função que retorna o ano do arquivo.
def ano_arquivo(file):
    return datetime.datetime.fromtimestamp(os.stat(file).st_mtime).year

# %%
# Denfine a função que retorna um dicionário com a quantidade arquivos por diretório e a frequncia dos anos. 
def qtd_arquivo_dir(path):
    
    qtd_arq_dir = {}

    for root, dirs, files in os.walk(path):

        freq_ano = {}

        #print(root)

        split_dir = root.split('\\')
        nome_dir = split_dir[len(split_dir)-1]

        anos_arq = [ano_arquivo(os.path.join(root, f)) for f in files]

        for ano in anos_arq:
            freq_ano[ano] = anos_arq.count(ano)


        qtd_arq_dir[nome_dir] = len(files), freq_ano, root

        #print('----------------------------')

    return qtd_arq_dir

# %%
arquivos = list_files_path(path_origem)

# %%
dic = qtd_arquivo_dir(path_origem)

# %%
for i in dic:
    
    #Obtêm o diconário da frequencia de anos.
    dic_anos = dic[i][1]
    
    #Se o deiretório estiver vazio, passa para o proximo.
    if len(dic_anos) == 0:
        continue
    
    #Obtêm a chave com maior valor
    anoComMaisArquivos = max(dic_anos, key=dic_anos.get)
              
    print('Copiando arquivos do diretório: [', i, ']' )
    print('Ano com maior acorrência: ', anoComMaisArquivos)
    
    path_arq = dic[i][2]
    #print(path_arq) 
    
    dir_origem = os.path.abspath(path_arq)
    print('Origem  <------', dir_origem)
         
    dir_destino = os.path.join(path_destino, str(anoComMaisArquivos))
    dir_destino =  os.path.abspath(os.path.join(dir_destino, i))
    print('Destino ------>', dir_destino)
    
    #Cria o diretório
    criar_diretorio(dir_destino, recursivo=True)
         
    arquivos = os.listdir(dir_origem)
    
    qtd_arq = 0
    
    for f in arquivos:
        
        path_arquivo = os.path.join(dir_origem, f)
        
        if(os.path.isfile(path_arquivo)):
            qtd_arq +=1
            print('Arq |',qtd_arq,' de ', dic[i][0]  ,'|->', path_arquivo)
            #Copia os arquivos
            shutil.copy2(path_arquivo, dir_destino)
       
    print('\n')

print(' -------------------------- FIM Execução -------------------------- ')
# Out:
# Copiando arquivos do diretório: [ source_img ]
# Ano com maior acorrência:  2014
# Origem  <------ C:\Users\charlessodre\Documents\PastaVM\Estudos\OrganizadorArquivos\source_img
# Destino ------> C:\Users\charlessodre\Documents\PastaVM\Estudos\OrganizadorArquivos\DESTINO\2014\source_img
# Arq | 1  de  5 |-> C:\Users\charlessodre\Documents\PastaVM\Estudos\OrganizadorArquivos\source_img\DSC_0085.JPG
# Arq | 2  de  5 |-> C:\Users\charlessodre\Documents\PastaVM\Estudos\OrganizadorArquivos\source_img\DSC_0105.JPG
# Arq | 3  de  5 |-> C:\Users\charlessodre\Documents\PastaVM\Estudos\OrganizadorArquivos\source_img\IMG_6727.JPG
# Arq | 4  de  5 |-> C:\Users\charlessodre\Documents\PastaVM\Estudos\OrganizadorArquivos\source_img\IMG_8348.JPG
# Arq | 5  de  5 |-> C:\Users\charlessodre\Documents\PastaVM\Estudos\OrganizadorArquivos\source_img\Praia de Piratininga 2012 (100).JPG
#
#
# Copiando arquivos do diretório: [ Festa ]
# Ano com maior acorrência:  2010
# Origem  <------ C:\Users\charlessodre\Documents\PastaVM\Estudos\OrganizadorArquivos\source_img\Festa
# Destino ------> C:\Users\charlessodre\Documents\PastaVM\Estudos\OrganizadorArquivos\DESTINO\2010\Festa
# Arq | 1  de  6 |-> C:\Users\charlessodre\Documents\PastaVM\Estudos\OrganizadorArquivos\source_img\Festa\DSC_0002.JPG
# Arq | 2  de  6 |-> C:\Users\charlessodre\Documents\PastaVM\Estudos\OrganizadorArquivos\source_img\Festa\IMG_6549.jpg
# Arq | 3  de  6 |-> C:\Users\charlessodre\Documents\PastaVM\Estudos\OrganizadorArquivos\source_img\Festa\IMG_6556.jpg
# Arq | 4  de  6 |-> C:\Users\charlessodre\Documents\PastaVM\Estudos\OrganizadorArquivos\source_img\Festa\layon outline 2.jpg
# Arq | 5  de  6 |-> C:\Users\charlessodre\Documents\PastaVM\Estudos\OrganizadorArquivos\source_img\Festa\Layon outline.jpg
# Arq | 6  de  6 |-> C:\Users\charlessodre\Documents\PastaVM\Estudos\OrganizadorArquivos\source_img\Festa\layon outlline.jpg
#
#
# Copiando arquivos do diretório: [ Festa 2 ]
# Ano com maior acorrência:  2015
# Origem  <------ C:\Users\charlessodre\Documents\PastaVM\Estudos\OrganizadorArquivos\source_img\Festa\Festa 2
# Destino ------> C:\Users\charlessodre\Documents\PastaVM\Estudos\OrganizadorArquivos\DESTINO\2015\Festa 2
# Arq | 1  de  4 |-> C:\Users\charlessodre\Documents\PastaVM\Estudos\OrganizadorArquivos\source_img\Festa\Festa 2\IMG_0880.JPG
# Arq | 2  de  4 |-> C:\Users\charlessodre\Documents\PastaVM\Estudos\OrganizadorArquivos\source_img\Festa\Festa 2\IMG_0904.JPG
# Arq | 3  de  4 |-> C:\Users\charlessodre\Documents\PastaVM\Estudos\OrganizadorArquivos\source_img\Festa\Festa 2\IMG_1073.JPG
# Arq | 4  de  4 |-> C:\Users\charlessodre\Documents\PastaVM\Estudos\OrganizadorArquivos\source_img\Festa\Festa 2\SAM_2210.JPG
#
#
# Copiando arquivos do diretório: [ Festa 3 ]
# Ano com maior acorrência:  2014
# Origem  <------ C:\Users\charlessodre\Documents\PastaVM\Estudos\OrganizadorArquivos\source_img\Festa\Festa 2\Festa 3
# Destino ------> C:\Users\charlessodre\Documents\PastaVM\Estudos\OrganizadorArquivos\DESTINO\2014\Festa 3
# Arq | 1  de  3 |-> C:\Users\charlessodre\Documents\PastaVM\Estudos\OrganizadorArquivos\source_img\Festa\Festa 2\Festa 3\IMG_6729.JPG
# Arq | 2  de  3 |-> C:\Users\charlessodre\Documents\PastaVM\Estudos\OrganizadorArquivos\source_img\Festa\Festa 2\Festa 3\IMG_8269.JPG
# Arq | 3  de  3 |-> C:\Users\charlessodre\Documents\PastaVM\Estudos\OrganizadorArquivos\source_img\Festa\Festa 2\Festa 3\IMG_8272.JPG
#
#
# Copiando arquivos do diretório: [ Festa 4 ]
# Ano com maior acorrência:  2007
# Origem  <------ C:\Users\charlessodre\Documents\PastaVM\Estudos\OrganizadorArquivos\source_img\Festa\Festa 2\Festa 3\Festa 4
# Destino ------> C:\Users\charlessodre\Documents\PastaVM\Estudos\OrganizadorArquivos\DESTINO\2007\Festa 4
# Arq | 1  de  4 |-> C:\Users\charlessodre\Documents\PastaVM\Estudos\OrganizadorArquivos\source_img\Festa\Festa 2\Festa 3\Festa 4\DSC_0001.JPG
# Arq | 2  de  4 |-> C:\Users\charlessodre\Documents\PastaVM\Estudos\OrganizadorArquivos\source_img\Festa\Festa 2\Festa 3\Festa 4\SAM_2170.JPG
# Arq | 3  de  4 |-> C:\Users\charlessodre\Documents\PastaVM\Estudos\OrganizadorArquivos\source_img\Festa\Festa 2\Festa 3\Festa 4\SAM_2508.JPG
# Arq | 4  de  4 |-> C:\Users\charlessodre\Documents\PastaVM\Estudos\OrganizadorArquivos\source_img\Festa\Festa 2\Festa 3\Festa 4\SAM_2509.JPG
#
#
# Copiando arquivos do diretório: [ Fasta 5 ]
# Ano com maior acorrência:  2014
# Origem  <------ C:\Users\charlessodre\Documents\PastaVM\Estudos\OrganizadorArquivos\source_img\Festa\Festa 2\Festa 3\Festa 4\Fasta 5
# Destino ------> C:\Users\charlessodre\Documents\PastaVM\Estudos\OrganizadorArquivos\DESTINO\2014\Fasta 5
# Arq | 1  de  2 |-> C:\Users\charlessodre\Documents\PastaVM\Estudos\OrganizadorArquivos\source_img\Festa\Festa 2\Festa 3\Festa 4\Fasta 5\IMG_20140421_193038.jpg
# Arq | 2  de  2 |-> C:\Users\charlessodre\Documents\PastaVM\Estudos\OrganizadorArquivos\source_img\Festa\Festa 2\Festa 3\Festa 4\Fasta 5\Mãe e Carlos.jpg
#
#
# Copiando arquivos do diretório: [ Natal ]
# Ano com maior acorrência:  2012
# Origem  <------ C:\Users\charlessodre\Documents\PastaVM\Estudos\OrganizadorArquivos\source_img\Natal
# Destino ------> C:\Users\charlessodre\Documents\PastaVM\Estudos\OrganizadorArquivos\DESTINO\2012\Natal
# Arq | 1  de  7 |-> C:\Users\charlessodre\Documents\PastaVM\Estudos\OrganizadorArquivos\source_img\Natal\15 anos Byanca 12-05-2012 (21).JPG
# Arq | 2  de  7 |-> C:\Users\charlessodre\Documents\PastaVM\Estudos\OrganizadorArquivos\source_img\Natal\IMG_1065.JPG
# Arq | 3  de  7 |-> C:\Users\charlessodre\Documents\PastaVM\Estudos\OrganizadorArquivos\source_img\Natal\IMG_20131224_224936.jpg
# Arq | 4  de  7 |-> C:\Users\charlessodre\Documents\PastaVM\Estudos\OrganizadorArquivos\source_img\Natal\IMG_20131224_225445.jpg
# Arq | 5  de  7 |-> C:\Users\charlessodre\Documents\PastaVM\Estudos\OrganizadorArquivos\source_img\Natal\IMG_3546.JPG
# Arq | 6  de  7 |-> C:\Users\charlessodre\Documents\PastaVM\Estudos\OrganizadorArquivos\source_img\Natal\Natal 2012 (20).JPG
# Arq | 7  de  7 |-> C:\Users\charlessodre\Documents\PastaVM\Estudos\OrganizadorArquivos\source_img\Natal\Natal 2012 (42).JPG
#
#
# Copiando arquivos do diretório: [ Niver ]
# Ano com maior acorrência:  2012
# Origem  <------ C:\Users\charlessodre\Documents\PastaVM\Estudos\OrganizadorArquivos\source_img\Niver
# Destino ------> C:\Users\charlessodre\Documents\PastaVM\Estudos\OrganizadorArquivos\DESTINO\2012\Niver
# Arq | 1  de  5 |-> C:\Users\charlessodre\Documents\PastaVM\Estudos\OrganizadorArquivos\source_img\Niver\15 anos Byanca 12-05-2012 (11).JPG
# Arq | 2  de  5 |-> C:\Users\charlessodre\Documents\PastaVM\Estudos\OrganizadorArquivos\source_img\Niver\DSC01461.JPG
# Arq | 3  de  5 |-> C:\Users\charlessodre\Documents\PastaVM\Estudos\OrganizadorArquivos\source_img\Niver\IMG_4559.JPG
# Arq | 4  de  5 |-> C:\Users\charlessodre\Documents\PastaVM\Estudos\OrganizadorArquivos\source_img\Niver\NiverIsis2013 (57).jpg
# Arq | 5  de  5 |-> C:\Users\charlessodre\Documents\PastaVM\Estudos\OrganizadorArquivos\source_img\Niver\NiverIsis2013 (61).jpg
#
#
# Copiando arquivos do diretório: [ Outros ]
# Ano com maior acorrência:  2013
# Origem  <------ C:\Users\charlessodre\Documents\PastaVM\Estudos\OrganizadorArquivos\source_img\Outros
# Destino ------> C:\Users\charlessodre\Documents\PastaVM\Estudos\OrganizadorArquivos\DESTINO\2013\Outros
# Arq | 1  de  1 |-> C:\Users\charlessodre\Documents\PastaVM\Estudos\OrganizadorArquivos\source_img\Outros\IMG_3552.JPG
#
#
# Copiando arquivos do diretório: [ Vazio1 ]
# Ano com maior acorrência:  2012
# Origem  <------ C:\Users\charlessodre\Documents\PastaVM\Estudos\OrganizadorArquivos\source_img\Vazio\Vazio1
# Destino ------> C:\Users\charlessodre\Documents\PastaVM\Estudos\OrganizadorArquivos\DESTINO\2012\Vazio1
# Arq | 1  de  1 |-> C:\Users\charlessodre\Documents\PastaVM\Estudos\OrganizadorArquivos\source_img\Vazio\Vazio1\Praia de Piratininga 2012 (98).JPG
#
#
#  -------------------------- FIM Execução --------------------------
